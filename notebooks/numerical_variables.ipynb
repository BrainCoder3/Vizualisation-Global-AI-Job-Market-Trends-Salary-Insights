# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../data/ai_job_dataset.csv")
data.head()
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# 3              India            50
# ...

# %% [markdown]
# # About
#
# The AI & Data Job Salaries and Skills Dataset 2024-2025 is synthetically prepared and provides a detailed, global overview of job listings in artificial intelligence, data science, machine learning, and related fields. This dataset aggregates job postings from October 2024 to July 2025, capturing a wide spectrum of roles, required skills, compensation, and organizational attributes across multiple countries and industries.
#
# With over 15,000 entries, each record details the job title, salary (in USD and local currency), experience level, employment type, company location and size, remote work ratio, required technical skills, education and experience requirements, industry, posting and application dates, job description length, benefits score, and company name. This rich dataset is designed for data scientists, career analysts, HR professionals, and researchers interested in AI workforce trends, salary benchmarking, and skills demand analysis.

# %%
def distribution(colum_name):
    fig,axes =plt.subplots(2,2,figsize=(15,15))
    sns.kdeplot(data=data[colum_name],ax=axes[0,0],fill=True,alpha=0.6,color="#2E86C1")

    sns.histplot(data=data[colum_name],ax=axes[0,1],bins=30,color="red")

    sns.violinplot(data=data[colum_name],ax=axes[1,1], palette="Set2",inner="quartile")

    sns.set_theme(style='ticks')

    plt.show()


def extremeValues(column_name):
    fig ,axes =plt.subplots(1,2, figsize=(12,8))
    sns.boxplot(data=data,y=column_name,ax=axes[0])
    sns.scatterplot(data=data[column_name],ax=axes[1])


    plt.show()

# %% [markdown]
# # salary_usd colomn

# %% [markdown]
# ## 1. Etude de la distribution

# %%
distribution('salary_usd')
# Out:
# C:\Users\ouazz\AppData\Local\Temp\ipykernel_17832\1643486341.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data[colum_name],ax=axes[1,1], palette="Set2",inner="quartile")

# %% [markdown]
# ## Interprétation de la courbe de densité (salary_usd)
#
# **1. Forme de la distribution**
# - Distribution **unimodale** avec un pic unique
# - **Asymétrie positive** marquée (oblique à droite)  → les salaires élevés étirent la queue droite, caractéristique des distributions de revenus
# - Forme non symétrique caractéristique des distributions de revenus
#
# **2. Zones de concentration**
# - Forte densité autour de **75 000 - 100 000 USD** (partie large et haute) → plage salariale la plus fréquente pour les profils intermédiaires
# - Concentration maximale des salaires dans cette zone
# - Faible densité pour les salaires très élevés (> 250 000 USD)
#
# **3. Dispersion**
# - Courbe **étalée** sur une large plage (0 à 400 000+ USD)
# - **Variabilité importante** des salaires
# - Queue de distribution allongée vers la droite
#
# **Conclusion** : Distribution typique des salaires avec majorité concentrée dans les gammes inférieures à moyennes et proportion décroissante de salaires élevés.

# %% [markdown]
# ## Interprétation de l'histogramme (salary_usd) <br>
#
# **1. Forme de la distribution** <br>
# - Distribution **unimodale** avec un pic principal
# - **Asymétrie positive** marquée (oblique à droite)
# - Queue de distribution étendue vers les salaires élevés
#
# **2. Concentration des valeurs**
# - Forte concentration entre **50 000 et 100 000 USD** (fréquences maximales > 1400)
# - Pic maximal autour de **75 000 USD**
# - Diminution progressive des effectifs au-delà
#
# **3. Dispersion**
# - Dispersion **élevée** : étendue de 0 à plus de 350 000 USD
# - Variabilité importante des salaires
# - Répartition hétérogène des valeurs
#
# **Conclusion** : Distribution typique des revenus avec majorité de salaires inférieurs à moyens et proportion décroissante de salaires élevés.

# %% [markdown]
# ## 2. Valeurs Extremes

# %%
extremeValues('salary_usd')

# %% [markdown]
# **Analyse des valeurs extrêmes (salary_usd)** (**Scatterplot**)
# - Présence de valeurs extrêmes isolées atteignant environ 400 000 USD
# - Forte dispersion des salaires dans la partie supérieure de la distribution
# - Concentration majoritaire des observations en dessous de 200 000 USD
# - Absence de structure identifiable parmi les valeurs extrêmes (distribution aléatoire)
# - Échelle de salaire très étendue indiquant une forte hétérogénéité des rémunérations
#
# **General interpretation** (**Boxplot** )
# - Médiane d'environ 100 000 USD positionnée dans la partie inférieure de la boîte
# - Asymétrie positive marquée (distribution oblique à droite)
# - Forte dispersion des 50% des données centrales (intervalle interquartile étendu)
# - Variabilité globale importante, particulièrement vers les salaires élevés

# %% [markdown]
# # years experience

# %% [markdown]
# ## 1. Etude de la distribution

# %%
distribution('years_experience')
# Out:
# C:\Users\ouazz\AppData\Local\Temp\ipykernel_17832\1643486341.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data[colum_name],ax=axes[1,1], palette="Set2",inner="quartile")

# %% [markdown]
# ### Interprétation de l'histogramme de « years_experience »
#
# L'histogramme présenté montre la distribution de la variable quantitative « years_experience ». Voici les observations selon les critères d'analyse d’un histogramme :
#
# - **Forme globale** : La distribution est globalement symétrique et adopte une forme en cloche, ce qui évoque une distribution normale.
# - **Concentration des valeurs** : Les effectifs sont les plus élevés autour de 10 ans d'expérience, avec un pic atteignant environ 1750 individus.
# - **Dispersion** : Les valeurs s'étendent de 0 à 20 ans, ce qui indique une étendue modérée.
# - **Présence de plusieurs pics** : Un seul pic est visible, suggérant une population homogène.
# - **Valeurs extrêmes** : Aucune valeur aberrante n'est apparente ; les barres décroissent progressivement vers les extrémités.
#
# ### Interprétation de la courbe de densité (bell curve)
#
# La courbe de densité lissée de la même variable « years_experience » confirme les observations précédentes :
#
# - **Forme lissée** : La courbe est en forme de cloche, symétrique, typique d'une distribution normale.
# - **Présence de pics** : Un pic unique est bien marqué, correspondant à la zone de plus forte densité.
# - **Asymétrie** : La courbe est parfaitement symétrique, sans inclinaison vers la droite ou la gauche.
# - **Étendue des queues** : Les queues s'étendent de 0 à 20 ans, sans allongement excessif, ce qui confirme l'absence de valeurs extrêmes.
#
# Ces deux représentations univariées indiquent que la variable « years_experience » suit approximativement une loi normale centrée autour de 10 ans, avec une dispersion standard.

# %% [markdown]
# Based on the provided images, I only see two actual diagrams: one histogram and one density curve (the "bell curve").
#
# However, the third page of your instructions mentions **Box Plot** and **Violin Plot**.
#
# Since I do not have a third image file containing a box plot or violin plot, I cannot interpret a specific graphic. However, based on the instructions, here is a **sample interpretation** of what a **Box Plot** for the variable `years_experience` (0 to 20 years) *would* look like:
#
# ### Interprétation hypothétique d’une Boîte à Moustaches (Box Plot) pour « years_experience »
#
# - **Position de la médiane** : La ligne à l'intérieur de la boîte serait située au centre de la boîte (vers 10 ans), confirmant la symétrie observée dans l'histogramme. La moitié des individus ont donc moins de 10 ans d'expérience, l'autre moitié plus.
# - **L'étendue centrale (Q1 à Q3)** : La boîte s'étendrait probablement de 5 à 15 ans. Cela signifie que 50 % des données (l'intervalle interquartile) sont concentrées autour de la moyenne.
# - **La longueur des moustaches** : Les moustaches s'étendraient jusqu'aux valeurs minimum (0) et maximum (20) sans être excessivement longues, indiquant une dispersion modérée et cohérente avec une distribution normale.
# - **Les valeurs aberrantes** : Il n'y aurait probablement **aucun point** en dehors des moustaches. Cela confirme l'absence de valeurs extrêmes ou d'individus avec une expérience anormalement élevée ou basse par rapport au reste de la population.
# - **L'asymétrie** : La médiane étant au centre de la boîte et les moustaches étant de longueur égale, la boîte indiquerait une **symétrie parfaite**.

# %% [markdown]
# ## 2. Valeurs Extremes

# %%
extremeValues("years_experience")

# %% [markdown]
# ### Interprétation des valeurs extrêmes pour l'histogramme et la courbe de densité
#
# **Pour l'histogramme** (variable « years_experience ») :
# - **Valeurs extrêmes** : Les extrémités de l'histogramme se situent à 0 et à 20 ans d'expérience. Les effectifs correspondants sont très faibles (proches de 0), ce qui indique qu'il n'y a pas de valeurs aberrantes marquées. Aucune barre isolée ne dépasse nettement le reste de la distribution, confirmant l'absence de données extrêmes influentes.
#
# **Pour la courbe de densité** (lissée) :
# - **Étendue des queues** : La courbe s'étend de 0 à 20 ans, avec des queues symétriques et fines. L'absence de queues épaisses ou allongées traduit une faible probabilité d'observer des valeurs très éloignées de la moyenne. La densité diminue progressivement vers les bords, sans remontée en extrémité, ce qui exclut la présence de sous-populations extrêmes.
#
# Ces deux représentations univariées confirment que la distribution des années d'expérience est bien centrée autour de 10 ans et ne comporte pas de valeurs extrêmes aberrantes.

# %% [markdown]
# # job_description_length

# %% [markdown]
# ## 1. Etude de la distribution

# %%
distribution('job_description_length')
# Out:
# C:\Users\ouazz\AppData\Local\Temp\ipykernel_17832\1643486341.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data[colum_name],ax=axes[1,1], palette="Set2",inner="quartile")

# %% [markdown]
# ## 2. Valeurs Extremes

# %%
extremeValues('job_description_length')

# %% [markdown]
# # benefits_score

# %% [markdown]
# ## 1. Etude de la distribution

# %%
distribution('benefits_score')
# Out:
# C:\Users\ouazz\AppData\Local\Temp\ipykernel_17832\1643486341.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data[colum_name],ax=axes[1,1], palette="Set2",inner="quartile")

# %% [markdown]
# ## 2. Valeurs Extremes

# %%
extremeValues('benefits_score')
